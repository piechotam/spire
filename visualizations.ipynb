# %%
from visualizations.visualizations import plot_precision_recall_curve, similarity_boxplot
import numpy as np
import pandas as pd

# %%
precision_recall_sae = np.load("results/results_sae/precision_recall_history.npy")
precision_recall_clip = np.load("results/results_clip/precision_recall_history.npy")
matched_pairs_sae = pd.read_pickle("results/results_sae/matched_pairs.pkl")
matched_pairs_clip = pd.read_pickle("results/results_clip/matched_pairs.pkl")

# %%
plot_precision_recall_curve(precision_recall_sae, "SAE")

# %%
plot_precision_recall_curve(precision_recall_clip, "CLIP")

# %%
similarity_boxplot(matched_pairs=matched_pairs_sae, model_name="SAE")

# %%
similarity_boxplot(matched_pairs=matched_pairs_clip, model_name="CLIP")
